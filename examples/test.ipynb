# %%
from scipy.stats import halfnorm
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
import pandas as pd

# %%
fig, ax = plt.subplots(1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mean, var, skew, kurt = halfnorm.stats(moments='mvsk')

# %%
x = np.linspace(a.ppf(0.01),
               a.ppf(0.99), 100)
ax.plot(x, a.pdf(x),
          'r-', lw=5, alpha=0.6, label='halfnorm pdf')

# %%
x
# Out:
# array([1.01253347, 1.03842535, 1.06431722, 1.0902091 , 1.11610098,
#        1.14199286, 1.16788473, 1.19377661, 1.21966849, 1.24556036,
#        1.27145224, 1.29734412, 1.32323599, 1.34912787, 1.37501975,
#        1.40091163, 1.4268035 , 1.45269538, 1.47858726, 1.50447913,
#        1.53037101, 1.55626289, 1.58215477, 1.60804664, 1.63393852,
#        1.6598304 , 1.68572227, 1.71161415, 1.73750603, 1.76339791,
#        1.78928978, 1.81518166, 1.84107354, 1.86696541, 1.89285729,
#        1.91874917, 1.94464105, 1.97053292, 1.9964248 , 2.02231668,
#        2.04820855, 2.07410043, 2.09999231, 2.12588419, 2.15177606,
#        2.17766794, 2.20355982, 2.22945169, 2.25534357, 2.28123545,
#        2.30712733, 2.3330192 , 2.35891108, 2.38480296, 2.41069483,
#        2.43658671, 2.46247859, 2.48837046, 2.51426234, 2.54015422,
#        2.5660461 , 2.59193797, 2.61782985, 2.64372173, 2.6696136 ,
#        2.69550548, 2.72139736, 2.74728924, 2.77318111, 2.79907299,
# ...

# %%
var
# Out:
# array(0.36338023)

# %%
halfnorm(q=1,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-6517b750e0a2> in <module>
# ----> 1 halfnorm(q=1,)
#
# ~/.virtualenvs/desdeo-emo/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in __call__(self, *args, **kwds)
#     769
#     770     def __call__(self, *args, **kwds):
# --> 771         return self.freeze(*args, **kwds)
#     772     __call__.__doc__ = freeze.__doc__
#     773
#
# ~/.virtualenvs/desdeo-emo/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in freeze(self, *args, **kwds)
#     766
#     767         """
# --> 768         return rv_frozen(self, *args, **kwds)
#     769
#     770     def __call__(self, *args, **kwds):
#
# ~/.virtualenvs/desdeo-emo/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in __init__(self, dist, *args, **kwds)
# ...

# %%
a = pd.DataFrame(np.random.normal(size=(10000,), scale=0.15))

# %%
(abs(a)+1).plot.density()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
(abs(a)+1).max()
# Out:
# 0    1.573984
# dtype: float64

# %%
import scipy

# %%
rv_continuous(a=1,b=2)

# %%
np.asarray([0] * 6)
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
np.random.normal(size=6, scale=0.15)
# Out:
# array([-0.06120342,  0.07966284, -0.15851876,  0.01538782, -0.19518875,
#         0.06170417])
